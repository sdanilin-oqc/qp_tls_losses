# %%
import qp_tls_losses.qp_tls_functions as qpf
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import hbar, k
from scipy.special import k0
import math

# %%
n = 1
temps = np.linspace(0.01,0.3,101)
Q0 = 1e6
b1 = 0.5
D = 1
b2 = 0.5
f = 4.5e9
Q_TLS = []
Q_QP = []
Q_tot = []
y1_val = []
y2_val = []
y3_val = []
T_QP = []
T_QP_1 = []
A0 = 100
Tc = 1.12
tr_temp = 0.2
sat_temp = 0.2
s = 0.02
for T in temps:
    Q_TLS.append(1/qpf.tls_loss(n, T, Q0, b1, b2, D, f))
    y1_val.append(1/A0/np.exp(1.764*Tc/T))
    y2_val.append(math.sinh(hbar*2*np.pi*f/2/k/T))
    y3_val.append(k0(hbar*2*np.pi*f/2/k/T)*math.sinh(hbar*2*np.pi*f/2/k/T))
    T_QP.append(qpf.t_qp_approx(T, tr_temp, sat_temp, s))
    T_QP_1.append(qpf.t_qp_t(T,sat_temp,5))
    Q_QP.append(1/qpf.qp_loss(T_QP[-1],A0,sat_temp,5,Tc,f))
    Q_tot.append(1/(qpf.tls_loss(n, T, Q0, b1, b2, D, f)+qpf.qp_loss(T_QP[-1],A0,sat_temp,5,Tc,f)))

# %%
fig,ax = plt.subplots(1,1,figsize=(5,4))
ax.plot(temps,Q_TLS,'--b',label='TLS')
ax.plot(temps,Q_QP,'--r',label='QP')
ax.plot(temps,Q_tot,'-g',label='total')
# ax.plot(temps,y1_val)
# ax.plot(temps,y3_val)
ax1 = ax.twinx()
ax1.plot(temps,T_QP,'-m')
ax1.plot([0,0.3],[0,0.3],'--k')
ax1.set_ylabel('QP T [K]',color='m')
ax1.plot(temps,T_QP_1,'--m')
ax.legend()
ax.set_ylabel(r'$Q_i$')
ax.set_xlabel(r'T [K]')
ax.set_yscale('log')

# %%
import os
import re
import qp_tls_losses.res_analysis_CPW as resa
def natural_key(s):
    return [int(t) if t.isdigit() else t.lower()
            for t in re.split(r'(\d+)', s)]
data = {}
folder_path = r'G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data'
files = sorted(os.listdir(folder_path), key=natural_key)
for filename in files:
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        with open(file_path, 'r') as f:
            try:
                print(f'Processing: {file_path}')
                res_index, powers, fr, Qi, Qc, av_n, fr_err, Qi_err, Qc_err, R2, p_surf, p_MA, p_SA, p_MS = resa.read_data_from_hdf5_file(file_path)
                name_only = os.path.splitext(filename)[0]
                temperature = int(name_only.split("_")[-1].replace("mK", ""))
                data[filename] = {
                    'res_index': res_index,
                    'powers': powers,
                    'fr': fr,
                    'Qi' : Qi,
                    'Qc' : Qc,
                    'av_n' : av_n,
                    'fr_err' : fr_err,
                    'Qi_err' : Qi_err,
                    'Qc_err' : Qc_err,
                    'R2' : R2,
                    'temperature' : temperature,
                }
            except Exception as e:
                print(f' Error processing {file_path} : e')
data_for_Qi_graph = [data[fname]['Qi'] for fname in data]
data_for_fr = [np.mean(data[fname]['fr'],axis=1) for fname in data]
data_for_av_n = [data[fname]['av_n'] for fname in data]
#data_for_p_surf = [data[fname]['p_surf'] for fname in data]
data_for_qc_graph = [np.mean(data[fname]['Qc'],axis=1)  for fname in data]
labels = [key[:7] for key in data.keys()]
data_for_temperature= [data[fname]['temperature'] for fname in data]
data_for_powers = [data[fname]['powers'] for fname in data]
# Out:
# Processing: G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data\W137D58_merged_processed_30mK.hdf5
# Processing: G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data\W137D58_merged_processed_50mK.hdf5
# Processing: G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data\W137D58_merged_processed_75mK.hdf5
# Processing: G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data\W137D58_merged_processed_100mK.hdf5
# Processing: G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data\W137D58_merged_processed_125mK.hdf5
# Processing: G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data\W137D58_merged_processed_150mK.hdf5
# Processing: G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data\W137D58_merged_processed_175mK.hdf5
# Processing: G:\Shared drives\MSDE_Trade_Secrets\Projects\cryo_materials\cpw_resonators\2025\CD11_W137\temperature_measurements\processed_data\all_merged_data\W137D58_merged_processed_200mK.hdf5

# %%
np.shape(data_for_Qi_graph)
data_for_temperature
# np.shape(data_for_av_n)
# Out:
# [30, 50, 75, 100, 125, 150, 175, 200]

# %%
fig2,ax = plt.subplots(1,1,figsize=(5,4))
high_p_Qi = []
for ii,temp in enumerate(data_for_temperature):
    high_p_Qi.append(data_for_Qi_graph[ii][0][-1])
    ax.plot(data_for_av_n[ii][0],data_for_Qi_graph[ii][0],'o')
ax.set_xscale('log')
# ax.set_yscale('log')

# %%
temps = np.linspace(0.01,0.3,101)
f = np.mean(data_for_fr,axis=0)[0]
Q_QP = []
T_QP = []
A0 = 6
Tc = 1.2
tr_temp = 0.2
sat_temp = 0.15
s = 0.02
for T in temps:
    T_QP.append(qpf.T_QP_approx(T, tr_temp, sat_temp, s))
    Q_QP.append(1/qpf.qp_loss(T_QP[-1],A0,Tc,f))

# %%
temps = np.linspace(0.01,0.3,101)

def model_fit(x, a0, sat_temp):
    n=5
    tc=1.2
    f=np.mean(data_for_fr,axis=0)[0]
    return qpf.qp_loss(x,a0,sat_temp,n,tc,f)
    
from scipy.optimize import curve_fit

popt, pcov = curve_fit(
    model_fit,
    np.divide(data_for_temperature,1e3),
    high_p_Qi,
    p0=[2e2, 0.180]   # initial guesses for a, c
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 11
#       7     return qpf.qp_loss(x,a0,sat_temp,n,tc,f)
#       9 from scipy.optimize import curve_fit
# ---> 11 popt, pcov = curve_fit(
#      12     model_fit,
#      13     np.divide(data_for_temperature,1e3),
#      14     high_p_Qi,
#      15     p0=[2e2, 0.180]   # initial guesses for a, c
#      16 )
#
# File C:\repos\qp_tls_losses\.venv\Lib\site-packages\scipy\optimize\_minpack_py.py:1021, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1018 if ydata.size != 1 and n > ydata.size:
#    1019     raise TypeError(f"The number of func parameters={n} must not"
#    1020                     f" exceed the number of data points={ydata.size}")
# -> 1021 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#    1022 popt, pcov, infodict, errmsg, ier = res
#    1023 ysize = len(infodict['fvec'])
#
# File C:\repos\qp_tls_losses\.venv\Lib\site-packages\scipy\optimize\_minpack_py.py:426, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     424 if not isinstance(args, tuple):
#     425     args = (args,)
# --> 426 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     427 m = shape[0]
#     429 if n > m:
#
# File C:\repos\qp_tls_losses\.venv\Lib\site-packages\scipy\optimize\_minpack_py.py:24, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# File C:\repos\qp_tls_losses\.venv\Lib\site-packages\scipy\optimize\_minpack_py.py:523, in _lightweight_memoizer.<locals>._memoized_func(params)
#     520 elif _memoized_func.last_params is not None:
#     521     _memoized_func.skip_lookup = True
# --> 523 val = f(params)
#     525 if _memoized_func.last_params is None:
#     526     _memoized_func.last_params = np.copy(params)
#
# File C:\repos\qp_tls_losses\.venv\Lib\site-packages\scipy\optimize\_minpack_py.py:540, in _wrap_func.<locals>.func_wrapped(params)
#     539 def func_wrapped(params):
# --> 540     return func(xdata, *params) - ydata
#
# Cell In[18], line 7, in model_fit(x, a0, sat_temp)
#       5 tc=1.2
#       6 f=np.mean(data_for_fr,axis=0)[0]
# ----> 7 return qpf.qp_loss(x,a0,sat_temp,n,tc,f)
#
# File C:\repos\qp_tls_losses\src\qp_tls_losses\qp_tls_functions.py:13, in qp_loss(t, a0, sat_temp, n, tc, f)
#      11 def qp_loss(t,a0,sat_temp,n,tc,f):
#      12     t1=t_qp_t(t,sat_temp,n)
# ---> 13     return math.sinh(hbar*2*np.pi*f/2/k/t1)*k0(hbar*2*np.pi*f/2/k/t1)/a0/np.exp(1.764*tc/t1)
#
# TypeError: only 0-dimensional arrays can be converted to Python scalars

# %%
qpf.qp_loss(0.1,1e2,sat_temp,n,1.2,np.mean(data_for_fr,axis=0)[0])
# Out:
# np.float64(3.908892022849142e-06)

# %%
fig3,ax = plt.subplots(1,1,figsize=(5,4))
ax.plot(np.divide(data_for_temperature,1e3),high_p_Qi,'o')
ax.plot(temps,Q_QP,'--r',label='QP')
ax.set_xlabel('T [K]')
ax.set_ylabel(r'$Q_i$')
# Out:
# Text(0, 0.5, '$Q_i$')

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
plt.plot(temps,T_QP[0],label='3')
plt.plot(temps,T_QP[1],label='4')
plt.plot(temps,T_QP[2],label='5')
plt.plot(temps,T_QP[3],label='6')
plt.ylim([0,0.32])
plt.legend()

# %%
n = [3,4,5,6]
T_QP = np.zeros((len(n),len(temps)))
for ii,val in enumerate(n):
    for jj,T in enumerate(temps):
        T_QP[ii][jj] = qpf.T_QP_T(T,sat_temp,val)
